# %% [markdown]
# ## Prime Root (Primitive Root)
#
# 1. Überprüfen ob n möglich ist
#     1.1 n muss ein primzahl sein oder
#     1.2 n = p^k (p ist eine ungerade primzahl)
#     1.3 n = 2*p^k (p ist eine ungerade primzahl)
# 2. Phi(n) berechenen
#     2.1 Wen n ein primzahl ist dan phi(n) = p -1
#     2.2 Wen ich n dahrstellen kann von zwei primzahlen p und q dan gilt (p-1)*(q-1)
#     2.3 Dan müsssen wir herausrechen wie vile zahlen nicht teilerfremden sind
# 3. Jetzt sind die zahlen von phi(n) = {q1, q2, ...}

# %%
n = 7 #n_def(2, 3)


# Find a g if n is n a prime number

# We have to find phi(n) this reprecents the order. If the order is 6 



g = 5
print(n)
# Out:
# 7

# %% [markdown]
# Wen n ein primzahl ist
#
# 2. Die VerbindungDie direkte Verbindung zwischen beiden Konzepten lässt sich so zusammenfassen:Das theoretische Maximum: Der Satz von Euler gibt uns eine Obergrenze. Er sagt uns, dass für jedes teilerfremde Element $a^{\phi(n)} \equiv 1 \pmod n$ gelten muss. Die tatsächliche Ordnung eines Elements muss immer ein Teiler von $\phi(n)$ sein.Das Erreichen des Maximums: Eine Primitivwurzel ist ein Element, das dieses theoretische Maximum voll ausschöpft. Ihre Ordnung ist nicht nur ein Teiler von $\phi(n)$, sondern exakt $\phi(n)$.Ohne den Satz von Euler wüssten wir nicht, dass die maximale Ordnung $\phi(n)$ ist, und somit gäbe es auch keine Definition für eine Primitivwurzel.

# %%
phi_n = 7 - 1 # Weil 7 ein Primzahl ist
