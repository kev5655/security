# %% [markdown]
# ![image.png](attachment:image.png)

# %%
m = b'Hey'
print(f"Message Bits {len(m)}")
# Out:
# Message Bits 3

# %%
from cryptography.hazmat.primitives.asymmetric.ed25519 import Ed25519PrivateKey

private_key = Ed25519PrivateKey.generate()
signature = private_key.sign(m)
public_key = private_key.public_key()

# %%
import time
from datetime import datetime, timedelta

total_iterations = pow(2, len(m) * 8)
print(f"This is the range: {total_iterations}")

start_time = time.time()
print(f"Loop started at: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

for i in range(total_iterations):
    candidate_bytes = i.to_bytes(len(m), 'big')
    try:
        public_key.verify(signature, candidate_bytes)
        print(f"The message is: {candidate_bytes.decode('utf-8')}")
        break
    except:
        if i % 100000 == 0 and i > 0:
            elapsed = time.time() - start_time
            rate = i / elapsed if elapsed > 0 else 0
            if rate > 0:
                remaining_seconds = (total_iterations - i) / rate
                eta = datetime.now() + timedelta(seconds=remaining_seconds)
                print(
                    f"Now: {datetime.now().strftime('%H:%M:%S')} | "
                    f"Expected finish: {eta.strftime('%H:%M:%S')} | "
                    f"Elapsed: {elapsed:.1f}s | Remaining: {remaining_seconds:.1f}s"
                )
            else:
                print(
                    f"Now: {datetime.now().strftime('%H:%M:%S')} | "
                    "Expected finish: calculating..."
                )
# Out:
# This is the range: 16777216
# Loop started at: 2026-04-18 21:21:47
# Now: 21:21:57 | Expected finish: 21:49:55 | Elapsed: 10.1s | Remaining: 1678.2s
# Now: 21:22:07 | Expected finish: 21:49:35 | Elapsed: 19.9s | Remaining: 1648.5s
# Now: 21:22:19 | Expected finish: 21:51:59 | Elapsed: 32.4s | Remaining: 1780.2s
# Now: 21:22:29 | Expected finish: 21:50:54 | Elapsed: 41.7s | Remaining: 1705.8s
# Now: 21:22:38 | Expected finish: 21:50:22 | Elapsed: 51.1s | Remaining: 1664.5s
# Now: 21:22:52 | Expected finish: 21:52:09 | Elapsed: 65.2s | Remaining: 1757.1s
# Now: 21:23:02 | Expected finish: 21:51:39 | Elapsed: 74.8s | Remaining: 1717.1s
# Now: 21:23:11 | Expected finish: 21:51:18 | Elapsed: 84.5s | Remaining: 1686.6s
# Now: 21:23:22 | Expected finish: 21:51:19 | Elapsed: 95.0s | Remaining: 1676.6s
# Now: 21:23:32 | Expected finish: 21:51:10 | Elapsed: 105.1s | Remaining: 1658.5s
# Now: 21:23:48 | Expected finish: 21:52:29 | Elapsed: 120.8s | Remaining: 1721.3s
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
