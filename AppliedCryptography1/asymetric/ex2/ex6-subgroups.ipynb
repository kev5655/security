# %%
Z9s: list[int] = [1,2,4,5,7,8]


# Ord(Z9s) = 6
# Möglich ordungen der sub gruppen ist: [1,2,3]

# Triviale Untergruppen
s1 = [1]
s2 = [1,2,4,5,7,8]

# Folgende element noch testen: [2,4,5,7,8]
# x=8 => x^k
#   8*8 mod 9 = 1
#   8*8*8 mod 9 = 8
#   8*8*8*8 mod 9 = 1
#   ...
s3 = [1,8]

# x=7 => x^k
#   7*7 mod 9 = 4
#   7*7*7 mod 9 = 1
#   7*7*7*7 mod 9 = 7
#   7*7*7*7*7 mod 9 = 4
#   ...

# x=4 => x^k
#   4*4 mod 9 = 7
#   4*4*4 mod 9 = 1
#   4*4*4*4 mod 9 = 4
#   4*4*4*4*4 mod 9 = 7
#   ...
s4 = [1,4,7]

# x=5 => x^k
#   5*5 mod 9 = 7
#   5*5*5 mod 9 = 8
#   5*5*5*5 mod 9 = 4
#   5*5*5*5*5 mod 9 = 2
#   Erzeug die gesamte gruppe sommit untergruppe ist s2


# Wir haben s1,s2,s3,s4 als untergruppen
