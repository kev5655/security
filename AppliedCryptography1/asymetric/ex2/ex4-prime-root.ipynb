# %% [markdown]
# ## Prime Root (Primitive Root): Suche nach dem generator g
#
# 1. Überprüfen ob n möglich ist
#     1.1 n muss ein primzahl sein oder
#     1.2 n = p^k (p ist eine ungerade primzahl)
#     1.3 n = 2*p^k (p ist eine ungerade primzahl)
# 2. Phi(n) berechenen
#     2.1 Wen n ein primzahl ist dan phi(n) = p -1
#     2.2 Wen ich n dahrstellen kann von zwei primzahlen p und q dan gilt (p-1)*(q-1)
#     2.3 Dan müsssen wir herausrechen wie vile zahlen nicht teilerfremden sind
# 3. Jetzt sind die zahlen von phi(n) = {q1, q2, ...}
# 4. {q1, q2, ...} Testen ob sie ein generator sind
#     4.1 Wen die ord(q1) = Ord(G) ist dan ist es ein generator
#         Die ord(q1) ist die anzal an element die es gibt befor ein 1 kommt wen wir q1^{1,..n} rechnen, die möglichen ordungen sind immer teiler von der gruppen ordung Ord(G)

# %%
# 1. Testen ja 7 ist ein primzahl somit i.o.
n = 7

# 2. phi(n)
# Da n eine prim ist gilt
phi_n = n-1

# Die Teilerfremden teiler sind
# Das sind auch die möglichen kandidaten für ein generator zu sein.
g = [1,2,3,4,5,6]

# 1: Kann nie ein generator sein da 1^1 = 1, 1^2 = 1, ... ord(1) = 1
g = [2,3,4,5,6]

# 6: Kann auch kein gnerator sein da 6^1 = 6, 6^2 = 1, 6^1 = 6 => ord(6) = 2
g = [2,3,4,5]

# 2: 2^1 = 2, 2^2 = 4, 2^3 = 1 => ord(2) = 3 != Ord(G)
g = [3,4,5]

# 4: 4^1 = 4, 4^2 = 2, 4^3 = 1 => ord(2) = 3 != Ord(G)

g = [3,5]

# 3: 
for i in range(1,n):
    print(f"3^{i} = {pow(3, i, n)}")
print("3 Ist ein generator\n")


# 5: 
for i in range(1,n):
    print(f"5^{i} = {pow(5, i, n)}")
print("5 Ist ein generator")
# Out:
# 3^1 = 3
# 3^2 = 2
# 3^3 = 6
# 3^4 = 4
# 3^5 = 5
# 3^6 = 1
# 3 Ist ein generator
#
# 5^1 = 5
# 5^2 = 4
# 5^3 = 6
# 5^4 = 2
# 5^5 = 3
# 5^6 = 1
# 5 Ist ein generator
