# %% [markdown]
# n = p * q
#
# phi = (p − 1)(q − 1)
#
# e = Choose an integer e < phi such that e and phi are co-prime
#
# ![image-2.png](attachment:image-2.png)

# %%
#      n   e
pk = (221, 5)
#      n   d
sk = (221, 77)

m = 6

def encrypt(n: int, e: int, m: int):
    return pow(m, e, n)

def decrypt(n: int, d: int, c: int):
    return pow(c, d, n)



if __name__ == "__main__":
    cipher_text = encrypt(pk[0], pk[1], m)
    print(f'Encrypted message: {cipher_text}')
    message = decrypt(sk[0], sk[1], cipher_text)
    print(f'Decrypted message: {message}')
# Out:
# Encrypted message: 41
# Decrypted message: 6
